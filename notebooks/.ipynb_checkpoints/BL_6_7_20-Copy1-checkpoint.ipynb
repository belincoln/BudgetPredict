# %%
import os
import requests
import numpy as np
import pandas as pd
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from scipy import optimize
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
import glob
import json

# %%
# read all csv files within the test_data folder. This should be 2008-2018 (11 years), of DHS contract award data
all_files = glob.glob("../data/*.csv")

li = []

for filename in all_files:
    df = pd.read_csv(filename, header = 0, usecols = ['contract_transaction_unique_key',
                        'contract_award_unique_key',
                        'federal_action_obligation','total_dollars_obligated', 'base_and_exercised_options_value', 
                        'current_total_value_of_award', 'base_and_all_options_value','potential_total_value_of_award',
                        'action_date'],
                 dtype = {'contract_transaction_unique_key':'str','contract_transaction_unique_key':'str',
                          'federal_action_obligation': 'float','total_dollars_obligated': 'float', 
                          'base_and_exercised_options_value': 'float', 'current_total_value_of_award': 'float', 
                          'base_and_all_options_value': 'float','potential_total_value_of_award': 'float',
                          'action_date':'str'})
    li.append(df)

df = pd.concat(li, axis=0, ignore_index=True)

# %%
df.head()
# Out:
#                    contract_transaction_unique_key  \
# 0      7014_4730_HSBP20080015201839_0_GS21F0031U_0
# 1  7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-
# 2           7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0
# 3       7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-
# 4           7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0
#
#                           contract_award_unique_key  \
# 0  CONT_AWD_HSBP20080015201839_7014_GS21F0031U_4730
# 1                      CONT_IDV_HSHQDC06C00065_7001
# 2       CONT_AWD_HSCG2808P7ABEC9_7008_-NONE-_-NONE-
# 3                      CONT_IDV_HSHQDC08C00190_7001
# 4       CONT_AWD_HSCG4508P6K4ZHT_7008_-NONE-_-NONE-
#
#    federal_action_obligation  total_dollars_obligated  \
# 0                    7830.75                      NaN
# 1                       0.00                      NaN
# 2                    -122.00                      NaN
# 3                  492248.00                      NaN
# 4                   25218.00                      NaN
#
#    base_and_exercised_options_value  current_total_value_of_award  \
# 0                           7830.75                           NaN
# 1                              0.00                           NaN
# 2                           -122.00                           NaN
# 3                              0.00                           NaN
# 4                          25218.00                           NaN
#
#    base_and_all_options_value  potential_total_value_of_award action_date
# 0                     7830.75                             NaN  2008-09-30
# 1                        0.00                             NaN  2008-09-30
# 2                     -122.00                             NaN  2008-09-30
# 3                   492248.00                             NaN  2008-09-30
# 4                    25218.00                             NaN  2008-09-30

# %%
# This is what we are using for our rate of Execution
df['Percent Cumulatively Obligated over potential total value of award'] = df['total_dollars_obligated'] / df['potential_total_value_of_award']

# Create Indicator Variable
df['Indicator'] = df['federal_action_obligation']<-1000

# %% [markdown]
# ##Separate contracts that have a deobligation

# %%
#Separate contracts that have a deobligation
df_deob = df.copy().loc[df['Indicator'] == 1]

# %%
#Get first deobligation date of contracts

df_first_deob = df_deob.copy()
df_first_deob = df_first_deob[['contract_award_unique_key', 'action_date']]
df_first_deob = df_first_deob.groupby(['contract_award_unique_key'], as_index = False).min()
df_first_deob.rename(columns = {'action_date':'first_deob_date'}, inplace = True)
df_first_deob['first_deob_date'] = pd.to_datetime(df_first_deob['first_deob_date'])

# %%
#Add indicator flag for contracts that ever have deobligation
df_deob.drop(columns = [c for c in df_deob.columns if c not in ['Indicator', 'contract_award_unique_key']], inplace = True)
df_deob = df_deob.drop_duplicates()
df_deob.rename(columns = {'Indicator': 'Contract_deob'}, inplace = True)
df_ever_deob = df.merge(df_deob, how = 'left', right_on = 'contract_award_unique_key', left_on = 'contract_award_unique_key')
df_ever_deob.rename(columns = {'Indicator': 'Transaction_Deob'}, inplace = True)
df_ever_deob['Contract_deob'] = df_ever_deob['Contract_deob'].fillna(False)

# %%
df_ever_deob.head(10)
# Out:
#                    contract_transaction_unique_key  \
# 0      7014_4730_HSBP20080015201839_0_GS21F0031U_0
# 1  7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-
# 2           7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0
# 3       7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-
# 4           7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0
# 5           7009_4730_HSSS0108F0077_1_GS35F0503M_0
# 6            7001_-NONE-_HSHQDC08P00224_0_-NONE-_0
# 7      7022_4730_HSFEEM05F0317_P00011_GS35F4274D_0
# 8            7014_-NONE-_HSBP1008P24180_0_-NONE-_0
# 9        7022_-NONE-_HSFE0708P1246_P00001_-NONE-_0
#
#                           contract_award_unique_key  \
# 0  CONT_AWD_HSBP20080015201839_7014_GS21F0031U_4730
# 1                      CONT_IDV_HSHQDC06C00065_7001
# 2       CONT_AWD_HSCG2808P7ABEC9_7008_-NONE-_-NONE-
# 3                      CONT_IDV_HSHQDC08C00190_7001
# 4       CONT_AWD_HSCG4508P6K4ZHT_7008_-NONE-_-NONE-
# 5       CONT_AWD_HSSS0108F0077_7009_GS35F0503M_4730
# 6        CONT_AWD_HSHQDC08P00224_7001_-NONE-_-NONE-
# 7       CONT_AWD_HSFEEM05F0317_7022_GS35F4274D_4730
# 8        CONT_AWD_HSBP1008P24180_7014_-NONE-_-NONE-
# 9         CONT_AWD_HSFE0708P1246_7022_-NONE-_-NONE-
#
#    federal_action_obligation  total_dollars_obligated  \
# 0                    7830.75                      NaN
# 1                       0.00                      NaN
# 2                    -122.00                      NaN
# 3                  492248.00                      NaN
# 4                   25218.00                      NaN
# 5                   28000.00                      NaN
# 6                    3600.00                      NaN
# 7                       0.00                      NaN
# 8                   14297.90                      NaN
# 9                       0.00                      NaN
#
#    base_and_exercised_options_value  current_total_value_of_award  \
# 0                           7830.75                           NaN
# 1                              0.00                           NaN
# 2                           -122.00                           NaN
# 3                              0.00                           NaN
# 4                          25218.00                           NaN
# 5                          28000.00                           NaN
# 6                           3600.00                           NaN
# 7                        1097873.00                           NaN
# 8                          14297.90                           NaN
# 9                              0.00                           NaN
#
#    base_and_all_options_value  potential_total_value_of_award action_date  \
# 0                     7830.75                             NaN  2008-09-30
# 1                        0.00                             NaN  2008-09-30
# 2                     -122.00                             NaN  2008-09-30
# 3                   492248.00                             NaN  2008-09-30
# 4                    25218.00                             NaN  2008-09-30
# 5                    28000.00                             NaN  2008-09-30
# 6                     3600.00                             NaN  2008-09-30
# 7                   -49451.92                             NaN  2008-09-30
# 8                    14297.90                             NaN  2008-09-30
# 9                        0.00                             NaN  2008-09-30
#
#    Percent Cumulatively Obligated over potential total value of award  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#    Transaction_Deob  Contract_deob
# 0             False          False
# 1             False          False
# 2             False          False
# 3             False          False
# 4             False          False
# 5             False           True
# 6             False           True
# 7             False          False
# 8             False          False
# 9             False          False

# %%
#Merge first deobligation date
contract_df = df_ever_deob.merge(df_first_deob, how = 'left', right_on = 'contract_award_unique_key', left_on = 'contract_award_unique_key')

# %%
contract_df.head()
# Out:
#                    contract_transaction_unique_key  \
# 0      7014_4730_HSBP20080015201839_0_GS21F0031U_0
# 1  7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-
# 2           7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0
# 3       7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-
# 4           7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0
#
#                           contract_award_unique_key  \
# 0  CONT_AWD_HSBP20080015201839_7014_GS21F0031U_4730
# 1                      CONT_IDV_HSHQDC06C00065_7001
# 2       CONT_AWD_HSCG2808P7ABEC9_7008_-NONE-_-NONE-
# 3                      CONT_IDV_HSHQDC08C00190_7001
# 4       CONT_AWD_HSCG4508P6K4ZHT_7008_-NONE-_-NONE-
#
#    federal_action_obligation  total_dollars_obligated  \
# 0                    7830.75                      NaN
# 1                       0.00                      NaN
# 2                    -122.00                      NaN
# 3                  492248.00                      NaN
# 4                   25218.00                      NaN
#
#    base_and_exercised_options_value  current_total_value_of_award  \
# 0                           7830.75                           NaN
# 1                              0.00                           NaN
# 2                           -122.00                           NaN
# 3                              0.00                           NaN
# 4                          25218.00                           NaN
#
#    base_and_all_options_value  potential_total_value_of_award action_date  \
# 0                     7830.75                             NaN  2008-09-30
# 1                        0.00                             NaN  2008-09-30
# 2                     -122.00                             NaN  2008-09-30
# 3                   492248.00                             NaN  2008-09-30
# 4                    25218.00                             NaN  2008-09-30
#
#    Percent Cumulatively Obligated over potential total value of award  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Transaction_Deob  Contract_deob first_deob_date
# 0             False          False             NaT
# 1             False          False             NaT
# 2             False          False             NaT
# 3             False          False             NaT
# 4             False          False             NaT

# %%
#test cell, there should be both types of values in both indicator columns
print(contract_df['Contract_deob'].value_counts())
print(contract_df['Transaction_Deob'].value_counts())
print(df_deob.shape)
# Out:
# False    780742
# True     244459
# Name: Contract_deob, dtype: int64
# False    952774
# True      72427
# Name: Transaction_Deob, dtype: int64
# (70069, 2)

# %% [markdown]
# # Quick Fix: Need long term solution to contracts that don't have de-obligations, thus don't have a value for the 'first_deob_date'

# %%
contract_df['first_deob_date'].fillna('2030-01-01',inplace = True)
contract_df['first_deob_date'].unique()
# Out:
# array(['2030-01-01', Timestamp('2010-09-08 00:00:00'),
#        Timestamp('2014-09-06 00:00:00'), ...,
#        Timestamp('2019-01-22 00:00:00'), Timestamp('2018-12-25 00:00:00'),
#        Timestamp('2018-10-08 00:00:00')], dtype=object)

# %%
#removing rows after first deobligation
# Something is wrong with this cell; it deletes all transactions that are on contracts that don't have de-obligations
# -Bennett
contract_df['action_date'] = pd.to_datetime(contract_df['action_date'])
contract_df['first_deob_date'] = pd.to_datetime(contract_df['first_deob_date'])

contract_df = contract_df[contract_df['action_date'] <= contract_df['first_deob_date']]

# %%
#Test cell
dftest3 = contract_df[contract_df['contract_award_unique_key'] == 'CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000'].sort_values(by = 'action_date')

dftest3.head(10)
# Out:
#                       contract_transaction_unique_key  \
# 178258       7013_8000_HSTS0310JCIO071_0_NNG07DA46B_0
# 305104  7013_8000_HSTS0310JCIO071_P00001_NNG07DA46B_0
# 405575  7013_8000_HSTS0310JCIO071_P00002_NNG07DA46B_0
# 394646  7013_8000_HSTS0310JCIO071_P00003_NNG07DA46B_0
#
#                             contract_award_unique_key  \
# 178258  CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
# 305104  CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
# 405575  CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
# 394646  CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
#
#         federal_action_obligation  total_dollars_obligated  \
# 178258                 3885103.94                      NaN
# 305104                 3344677.82                      NaN
# 405575                 2994025.93                      NaN
# 394646                 -402426.96                      NaN
#
#         base_and_exercised_options_value  current_total_value_of_award  \
# 178258                        3885103.94                           NaN
# 305104                        3344677.82                           NaN
# 405575                        2994025.93                           NaN
# 394646                        -402426.96                           NaN
#
#         base_and_all_options_value  potential_total_value_of_award  \
# 178258                 10223807.69                             NaN
# 305104                        0.00                             NaN
# 405575                        0.00                             NaN
# 394646                  -402426.96                             NaN
#
#        action_date  \
# 178258  2010-09-30
# 305104  2011-06-16
# 405575  2012-05-04
# 394646  2012-06-21
#
#         Percent Cumulatively Obligated over potential total value of award  \
# 178258                                                NaN
# 305104                                                NaN
# 405575                                                NaN
# 394646                                                NaN
#
#         Transaction_Deob  Contract_deob first_deob_date
# 178258             False           True      2012-06-21
# 305104             False           True      2012-06-21
# 405575             False           True      2012-06-21
# 394646              True           True      2012-06-21

# %%
#Get first action date of all contracts

df_first_date = contract_df.copy()
df_first_date = df_first_date[['contract_award_unique_key', 'action_date']]
df_first_date = df_first_date.groupby(['contract_award_unique_key'] , as_index = False).min()
df_first_date.rename(columns = {'action_date': 'first_date'}, inplace = True)
df_first_date.head()
# Out:
#                 contract_award_unique_key first_date
# 0  CONT_AWD_00001_7022_HSFE0408A0017_7022 2008-02-15
# 1  CONT_AWD_00001_7022_HSFE0408A0035_7022 2008-02-20
# 2  CONT_AWD_00001_7022_HSFE0408A0066_7022 2008-05-15
# 3  CONT_AWD_00001_7022_HSFE0408A0067_7022 2008-03-31
# 4  CONT_AWD_00001_7022_HSFE0408A0069_7022 2008-03-26

# %%
#test cell
df_test_first_date = df_first_date.copy()

df_test_first_date = df_first_date[df_first_date['contract_award_unique_key'] == 'CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000']
df_test_first_date.head()
# Out:
#                            contract_award_unique_key first_date
# 67072  CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000 2010-09-30

# %%
contract_df = contract_df.merge(df_first_date, how = 'left', right_on = 'contract_award_unique_key', left_on = 'contract_award_unique_key')
contract_df['action_date'] = pd.to_datetime(contract_df['action_date'])
contract_df['first_date'] = pd.to_datetime(contract_df['first_date'])
contract_df['days_since_first_action'] = contract_df['action_date'] - contract_df['first_date']

# %%
#test cell
contract_df_test = contract_df.copy()
contract_df_test = contract_df_test[contract_df_test['contract_award_unique_key'] == 'CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000'].sort_values(by = 'action_date')
contract_df_test.head()
# Out:
#                       contract_transaction_unique_key  \
# 171889       7013_8000_HSTS0310JCIO071_0_NNG07DA46B_0
# 291779  7013_8000_HSTS0310JCIO071_P00001_NNG07DA46B_0
# 385644  7013_8000_HSTS0310JCIO071_P00002_NNG07DA46B_0
# 375408  7013_8000_HSTS0310JCIO071_P00003_NNG07DA46B_0
#
#                             contract_award_unique_key  \
# 171889  CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
# 291779  CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
# 385644  CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
# 375408  CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
#
#         federal_action_obligation  total_dollars_obligated  \
# 171889                 3885103.94                      NaN
# 291779                 3344677.82                      NaN
# 385644                 2994025.93                      NaN
# 375408                 -402426.96                      NaN
#
#         base_and_exercised_options_value  current_total_value_of_award  \
# 171889                        3885103.94                           NaN
# 291779                        3344677.82                           NaN
# 385644                        2994025.93                           NaN
# 375408                        -402426.96                           NaN
#
#         base_and_all_options_value  potential_total_value_of_award  \
# 171889                 10223807.69                             NaN
# 291779                        0.00                             NaN
# 385644                        0.00                             NaN
# 375408                  -402426.96                             NaN
#
#        action_date  \
# 171889  2010-09-30
# 291779  2011-06-16
# 385644  2012-05-04
# 375408  2012-06-21
#
#         Percent Cumulatively Obligated over potential total value of award  \
# 171889                                                NaN
# 291779                                                NaN
# 385644                                                NaN
# 375408                                                NaN
#
#         Transaction_Deob  Contract_deob first_deob_date first_date  \
# 171889             False           True      2012-06-21 2010-09-30
# 291779             False           True      2012-06-21 2010-09-30
# 385644             False           True      2012-06-21 2010-09-30
# 375408              True           True      2012-06-21 2010-09-30
#
#        days_since_first_action
# 171889                  0 days
# 291779                259 days
# 385644                582 days
# 375408                630 days

# %%
#Contract_df now has the contract/transaction deobligation flags and days since the first action date

# %%
# Adding in transaction number
g = contract_df.groupby(['contract_award_unique_key'])

contract_df['transaction_num'] = g['action_date'].rank(method = 'min')
contract_df.drop(columns = ['first_deob_date'], inplace = True)

# %%
contract_df.copy()
# Out:
#                            contract_transaction_unique_key  \
# 0              7014_4730_HSBP20080015201839_0_GS21F0031U_0
# 1          7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-
# 2                   7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0
# 3               7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-
# 4                   7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0
# ...                                                    ...
# 1025196      7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0
# 1025197           7008_-NONE-_70Z02819P7W100700_0_-NONE-_0
# 1025198  7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS...
# 1025199    7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-
# 1025200      7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0
#
#                                  contract_award_unique_key  \
# 0         CONT_AWD_HSBP20080015201839_7014_GS21F0031U_4730
# 1                             CONT_IDV_HSHQDC06C00065_7001
# 2              CONT_AWD_HSCG2808P7ABEC9_7008_-NONE-_-NONE-
# 3                             CONT_IDV_HSHQDC08C00190_7001
# 4              CONT_AWD_HSCG4508P6K4ZHT_7008_-NONE-_-NONE-
# ...                                                    ...
# 1025196      CONT_AWD_70Z04219PQNE10500_7008_-NONE-_-NONE-
# 1025197      CONT_AWD_70Z02819P7W100700_7008_-NONE-_-NONE-
# 1025198  CONT_AWD_70CMSD18FR0000233_7012_GS00Q14OADS138...
# 1025199                       CONT_IDV_HSHQC715D00005_7001
# 1025200      CONT_AWD_70Z02919PMX003A00_7008_-NONE-_-NONE-
#
#          federal_action_obligation  total_dollars_obligated  \
# 0                          7830.75                      NaN
# 1                             0.00                      NaN
# 2                          -122.00                      NaN
# 3                        492248.00                      NaN
# 4                         25218.00                      NaN
# ...                            ...                      ...
# 1025196                    2052.00                  4104.00
# 1025197                       0.00                     0.00
# 1025198                       0.00               1145702.18
# 1025199                       0.00                     0.00
# 1025200                    2150.37                  2867.16
#
#          base_and_exercised_options_value  current_total_value_of_award  \
# 0                                 7830.75                           NaN
# 1                                    0.00                           NaN
# 2                                 -122.00                           NaN
# 3                                    0.00                           NaN
# 4                                25218.00                           NaN
# ...                                   ...                           ...
# 1025196                           2052.00                       4104.00
# 1025197                              0.00                          0.00
# 1025198                              0.00                    1145702.18
# 1025199                               NaN                           NaN
# 1025200                              0.00                       2867.16
#
#          base_and_all_options_value  potential_total_value_of_award  \
# 0                           7830.75                             NaN
# 1                              0.00                             NaN
# 2                           -122.00                             NaN
# 3                         492248.00                             NaN
# 4                          25218.00                             NaN
# ...                             ...                             ...
# 1025196                     2052.00                         4104.00
# 1025197                     1075.20                         1075.20
# 1025198                        0.00                      3390064.82
# 1025199                        0.00                     50139920.00
# 1025200                        0.00                         2867.16
#
#         action_date  \
# 0        2008-09-30
# 1        2008-09-30
# 2        2008-09-30
# 3        2008-09-30
# 4        2008-09-30
# ...             ...
# 1025196  2018-10-01
# 1025197  2018-10-01
# 1025198  2018-10-01
# 1025199  2018-10-01
# 1025200  2018-10-01
#
#          Percent Cumulatively Obligated over potential total value of award  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# ...                                                    ...
# 1025196                                           1.000000
# 1025197                                           0.000000
# 1025198                                           0.337959
# 1025199                                           0.000000
# 1025200                                           1.000000
#
#          Transaction_Deob  Contract_deob first_date days_since_first_action  \
# 0                   False          False 2008-09-30                  0 days
# 1                   False          False 2007-10-15                351 days
# 2                   False          False 2008-08-20                 41 days
# 3                   False          False 2008-09-30                  0 days
# 4                   False          False 2008-09-30                  0 days
# ...                   ...            ...        ...                     ...
# 1025196             False          False 2018-10-01                  0 days
# 1025197             False          False 2018-10-01                  0 days
# 1025198             False          False 2018-09-27                  4 days
# 1025199             False          False 2015-06-01               1218 days
# 1025200             False          False 2018-10-01                  0 days
#
#          transaction_num
# 0                    1.0
# 1                   11.0
# 2                    2.0
# 3                    1.0
# 4                    1.0
# ...                  ...
# 1025196              1.0
# 1025197              1.0
# 1025198              2.0
# 1025199              9.0
# 1025200              1.0
#
# [1025201 rows x 15 columns]

# %%
#test cell
testdf = contract_df.copy()
testdf = testdf[testdf['contract_award_unique_key'] == 'CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000'].sort_values(by = 'transaction_num')
testdf.head(10)
# Out:
#                       contract_transaction_unique_key  \
# 47024        7013_8000_HSTS0310JCIO071_0_NNG07DA46B_0
# 80947   7013_8000_HSTS0310JCIO071_P00001_NNG07DA46B_0
# 108552  7013_8000_HSTS0310JCIO071_P00002_NNG07DA46B_0
# 105726  7013_8000_HSTS0310JCIO071_P00003_NNG07DA46B_0
#
#                             contract_award_unique_key  \
# 47024   CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
# 80947   CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
# 108552  CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
# 105726  CONT_AWD_HSTS0310JCIO071_7013_NNG07DA46B_8000
#
#         federal_action_obligation  total_dollars_obligated  \
# 47024                  3885103.94                      NaN
# 80947                  3344677.82                      NaN
# 108552                 2994025.93                      NaN
# 105726                 -402426.96                      NaN
#
#         base_and_exercised_options_value  current_total_value_of_award  \
# 47024                         3885103.94                           NaN
# 80947                         3344677.82                           NaN
# 108552                        2994025.93                           NaN
# 105726                        -402426.96                           NaN
#
#         base_and_all_options_value  potential_total_value_of_award  \
# 47024                  10223807.69                             NaN
# 80947                         0.00                             NaN
# 108552                        0.00                             NaN
# 105726                  -402426.96                             NaN
#
#        action_date  \
# 47024   2010-09-30
# 80947   2011-06-16
# 108552  2012-05-04
# 105726  2012-06-21
#
#         Percent Cumulatively Obligated over potential total value of award  \
# 47024                                                 NaN
# 80947                                                 NaN
# 108552                                                NaN
# 105726                                                NaN
#
#         Transaction_Deob  Contract_deob first_date days_since_first_action  \
# 47024              False           True 2010-09-30                  0 days
# 80947              False           True 2010-09-30                259 days
# 108552             False           True 2010-09-30                582 days
# 105726              True           True 2010-09-30                630 days
#
#         transaction_num
# 47024               1.0
# 80947               2.0
# 108552              3.0
# 105726              4.0

# %% [markdown]
# ## End Mike's changes 05/14/2020
# ## Beginning of Bennett's Edits

# %%
from sklearn.model_selection import train_test_split

# %%
df = contract_df.copy()

# %%
#Remove De-obligation Events
df = df[df['Transaction_Deob']==False]

# %%
df['Contract_deob'].value_counts()
# Out:
# False    780742
# True     172032
# Name: Contract_deob, dtype: int64

# %%
df.head(100)
# Out:
#                      contract_transaction_unique_key  \
# 0        7014_4730_HSBP20080015201839_0_GS21F0031U_0
# 1    7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-
# 2             7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0
# 3         7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-
# 4             7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0
# ..                                               ...
# 97              7022_-NONE-_HSFE0608P6314_0_-NONE-_0
# 98       7014_7001_HSBP1008F24198_0_HSHQPA05D00007_0
# 99            7008_-NONE-_HSCG4207PQNG269_1_-NONE-_0
# 100           7008_-NONE-_HSCG8008P3FAY00_1_-NONE-_0
# 101       7015_-NONE-_HSFLGL08C00002_P00002_-NONE-_0
#
#                             contract_award_unique_key  \
# 0    CONT_AWD_HSBP20080015201839_7014_GS21F0031U_4730
# 1                        CONT_IDV_HSHQDC06C00065_7001
# 2         CONT_AWD_HSCG2808P7ABEC9_7008_-NONE-_-NONE-
# 3                        CONT_IDV_HSHQDC08C00190_7001
# 4         CONT_AWD_HSCG4508P6K4ZHT_7008_-NONE-_-NONE-
# ..                                                ...
# 97          CONT_AWD_HSFE0608P6314_7022_-NONE-_-NONE-
# 98   CONT_AWD_HSBP1008F24198_7014_HSHQPA05D00007_7001
# 99        CONT_AWD_HSCG4207PQNG269_7008_-NONE-_-NONE-
# 100       CONT_AWD_HSCG8008P3FAY00_7008_-NONE-_-NONE-
# 101        CONT_AWD_HSFLGL08C00002_7015_-NONE-_-NONE-
#
#      federal_action_obligation  total_dollars_obligated  \
# 0                      7830.75                      NaN
# 1                         0.00                      NaN
# 2                      -122.00                      NaN
# 3                    492248.00                      NaN
# 4                     25218.00                      NaN
# ..                         ...                      ...
# 97                     2900.00                      NaN
# 98                   432816.54                      NaN
# 99                     -400.00                      NaN
# 100                    1483.00                      NaN
# 101                       0.00                      NaN
#
#      base_and_exercised_options_value  current_total_value_of_award  \
# 0                             7830.75                           NaN
# 1                                0.00                           NaN
# 2                             -122.00                           NaN
# 3                                0.00                           NaN
# 4                            25218.00                           NaN
# ..                                ...                           ...
# 97                            2900.00                           NaN
# 98                          432816.54                           NaN
# 99                            -400.00                           NaN
# 100                           1483.00                        3683.0
# 101                           8300.00                           NaN
#
#      base_and_all_options_value  potential_total_value_of_award action_date  \
# 0                       7830.75                             NaN  2008-09-30
# 1                          0.00                             NaN  2008-09-30
# 2                       -122.00                             NaN  2008-09-30
# 3                     492248.00                             NaN  2008-09-30
# 4                      25218.00                             NaN  2008-09-30
# ..                          ...                             ...         ...
# 97                      2900.00                             NaN  2008-09-30
# 98                    432816.54                             NaN  2008-09-30
# 99                      -400.00                             NaN  2008-09-30
# 100                     1483.00                          3683.0  2008-09-30
# 101                    16600.00                             NaN  2008-09-30
#
#      Percent Cumulatively Obligated over potential total value of award  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 97                                                 NaN
# 98                                                 NaN
# 99                                                 NaN
# 100                                                NaN
# 101                                                NaN
#
#      Transaction_Deob  Contract_deob first_date days_since_first_action  \
# 0               False          False 2008-09-30                  0 days
# 1               False          False 2007-10-15                351 days
# 2               False          False 2008-08-20                 41 days
# 3               False          False 2008-09-30                  0 days
# 4               False          False 2008-09-30                  0 days
# ..                ...            ...        ...                     ...
# 97              False           True 2008-09-30                  0 days
# 98              False          False 2008-09-30                  0 days
# 99              False          False 2008-09-30                  0 days
# 100             False          False 2008-08-21                 40 days
# 101             False           True 2007-10-01                365 days
#
#      transaction_num
# 0                1.0
# 1               11.0
# 2                2.0
# 3                1.0
# 4                1.0
# ..               ...
# 97               1.0
# 98               1.0
# 99               1.0
# 100              2.0
# 101              3.0
#
# [100 rows x 15 columns]

# %%
## We will use Contract De-Ob Flag to determine if the transaction is a part of a contract that will eventually get 
## De-obligated. 
## We are not saying when it will get de-obligated, just that it will eventually get de-obligated.

# %%
df = df['Percent Cumulatively Obligated over potential total value of award']

# %%
df.set_index('contract_transaction_unique_key')
# Out:
#                                                                             contract_award_unique_key  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0          CONT_AWD_HSBP20080015201839_7014_GS21F0031U_4730
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-                          CONT_IDV_HSHQDC06C00065_7001
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                    CONT_AWD_HSCG2808P7ABEC9_7008_-NONE-_-NONE-
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                               CONT_IDV_HSHQDC08C00190_7001
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                    CONT_AWD_HSCG4508P6K4ZHT_7008_-NONE-_-NONE-
# ...                                                                                               ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0           CONT_AWD_70Z04219PQNE10500_7008_-NONE-_-NONE-
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                CONT_AWD_70Z02819P7W100700_7008_-NONE-_-NONE-
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...  CONT_AWD_70CMSD18FR0000233_7012_GS00Q14OADS138...
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-                          CONT_IDV_HSHQC715D00005_7001
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0           CONT_AWD_70Z02919PMX003A00_7008_-NONE-_-NONE-
#
#                                                     federal_action_obligation  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0                           7830.75
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-                          0.00
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                                -122.00
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                          492248.00
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                               25218.00
# ...                                                                       ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0                         2052.00
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                                 0.00
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...                       0.00
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-                          0.00
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0                         2150.37
#
#                                                     total_dollars_obligated  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0                             NaN
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-                         NaN
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                                  NaN
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                              NaN
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                                  NaN
# ...                                                                     ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0                       4104.00
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                               0.00
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...               1145702.18
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-                        0.00
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0                       2867.16
#
#                                                     base_and_exercised_options_value  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0                                  7830.75
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-                                 0.00
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                                       -122.00
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                                      0.00
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                                      25218.00
# ...                                                                              ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0                                2052.00
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                                        0.00
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...                              0.00
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-                                  NaN
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0                                   0.00
#
#                                                     current_total_value_of_award  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0                                  NaN
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-                              NaN
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                                       NaN
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                                   NaN
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                                       NaN
# ...                                                                          ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0                            4104.00
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                                    0.00
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...                    1145702.18
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-                              NaN
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0                            2867.16
#
#                                                     base_and_all_options_value  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0                            7830.75
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-                           0.00
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                                 -122.00
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                           492248.00
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                                25218.00
# ...                                                                        ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0                          2052.00
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                               1075.20
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...                        0.00
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-                           0.00
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0                             0.00
#
#                                                     potential_total_value_of_award  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0                                    NaN
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-                                NaN
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                                         NaN
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                                     NaN
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                                         NaN
# ...                                                                            ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0                              4104.00
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                                   1075.20
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...                      3390064.82
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-                        50139920.00
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0                              2867.16
#
#                                                    action_date  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0         2008-09-30
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-     2008-09-30
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0              2008-09-30
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-          2008-09-30
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0              2008-09-30
# ...                                                        ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0       2018-10-01
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0            2018-10-01
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...  2018-10-01
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-     2018-10-01
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0       2018-10-01
#
#                                                     Percent Cumulatively Obligated over potential total value of award  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0                                                       NaN
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-                                                   NaN
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                                                            NaN
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                                                        NaN
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                                                            NaN
# ...                                                                                               ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0                                                1.000000
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                                                     0.000000
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...                                           0.337959
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-                                              0.000000
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0                                                1.000000
#
#                                                     Transaction_Deob  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0                    False
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-                False
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                         False
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                     False
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                         False
# ...                                                              ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0                  False
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                       False
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...             False
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-                False
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0                  False
#
#                                                     Contract_deob first_date  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0                 False 2008-09-30
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-             False 2007-10-15
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                      False 2008-08-20
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                  False 2008-09-30
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                      False 2008-09-30
# ...                                                           ...        ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0               False 2018-10-01
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                    False 2018-10-01
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...          False 2018-09-27
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-             False 2015-06-01
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0               False 2018-10-01
#
#                                                    days_since_first_action  \
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0                         0 days
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-                   351 days
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                             41 days
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                          0 days
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                              0 days
# ...                                                                    ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0                       0 days
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                            0 days
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...                  4 days
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-                  1218 days
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0                       0 days
#
#                                                     transaction_num
# contract_transaction_unique_key
# 7014_4730_HSBP20080015201839_0_GS21F0031U_0                     1.0
# 7001_-NONE-_HSHQDC06C00065_P00034_-NONE-_-NONE-                11.0
# 7008_-NONE-_HSCG2808P7ABEC9_1_-NONE-_0                          2.0
# 7001_-NONE-_HSHQDC08C00190_0_-NONE-_-NONE-                      1.0
# 7008_-NONE-_HSCG4508P6K4ZHT_0_-NONE-_0                          1.0
# ...                                                             ...
# 7008_-NONE-_70Z04219PQNE10500_P00001_-NONE-_0                   1.0
# 7008_-NONE-_70Z02819P7W100700_0_-NONE-_0                        1.0
# 7012_4732_70CMSD18FR0000233_P00001_GS00Q14OADS1...              2.0
# 7001_-NONE-_HSHQC715D00005_P00008_-NONE-_-NONE-                 9.0
# 7008_-NONE-_70Z02919PMX003A00_A00002_-NONE-_0                   1.0
#
# [952774 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['contract_transaction_unique_key', 'contract_award_unique_key',
#        'federal_action_obligation', 'total_dollars_obligated',
#        'base_and_exercised_options_value', 'current_total_value_of_award',
#        'base_and_all_options_value', 'potential_total_value_of_award',
#        'action_date',
#        'Percent Cumulatively Obligated over potential total value of award',
#        'Transaction_Deob', 'Contract_deob', 'first_date',
#        'days_since_first_action', 'transaction_num'],
#       dtype='object')

# %%
# Drop all columns except feature columns
df = df[['Contract_deob','total_dollars_obligated',
       'base_and_exercised_options_value', 'current_total_value_of_award',
       'base_and_all_options_value', 'potential_total_value_of_award','days_since_first_action', 'transaction_num',
         'Percent Cumulatively Obligated over potential total value of award']]

# %%
# Split contracts (not transactions!) into a test train set
contracts_train, contracts_test = train_test_split(df['contract_award_unique_key'], test_size = .2)

# %%
# creat new df to test
train_df = df[df['contract_award_unique_key'].isin(contracts_train)]

# %%
train_df.isnull()
# Out:
#         contract_transaction_unique_key  contract_award_unique_key  \
# 0                                 False                      False
# 1                                 False                      False
# 2                                 False                      False
# 3                                 False                      False
# 4                                 False                      False
# ...                                 ...                        ...
# 244454                            False                      False
# 244455                            False                      False
# 244456                            False                      False
# 244457                            False                      False
# 244458                            False                      False
#
#         federal_action_obligation  total_dollars_obligated  \
# 0                           False                     True
# 1                           False                     True
# 2                           False                     True
# 3                           False                     True
# 4                           False                     True
# ...                           ...                      ...
# 244454                      False                    False
# 244455                      False                    False
# 244456                      False                    False
# 244457                      False                    False
# 244458                      False                    False
#
#         base_and_exercised_options_value  current_total_value_of_award  \
# 0                                  False                          True
# 1                                  False                          True
# 2                                  False                          True
# 3                                  False                          True
# 4                                  False                          True
# ...                                  ...                           ...
# 244454                             False                         False
# 244455                             False                         False
# 244456                             False                         False
# 244457                             False                         False
# 244458                             False                         False
#
#         base_and_all_options_value  potential_total_value_of_award  \
# 0                            False                            True
# 1                            False                            True
# 2                            False                            True
# 3                            False                            True
# 4                            False                            True
# ...                            ...                             ...
# 244454                       False                           False
# 244455                       False                           False
# 244456                       False                           False
# 244457                       False                           False
# 244458                       False                           False
#
#         action_date  \
# 0             False
# 1             False
# 2             False
# 3             False
# 4             False
# ...             ...
# 244454        False
# 244455        False
# 244456        False
# 244457        False
# 244458        False
#
#         Percent Cumulatively Obligated over potential total value of award  \
# 0                                                    True
# 1                                                    True
# 2                                                    True
# 3                                                    True
# 4                                                    True
# ...                                                   ...
# 244454                                              False
# 244455                                              False
# 244456                                              False
# 244457                                              False
# 244458                                              False
#
#         Transaction_Deob  Contract_deob  first_date  days_since_first_action  \
# 0                  False          False       False                    False
# 1                  False          False       False                    False
# 2                  False          False       False                    False
# 3                  False          False       False                    False
# 4                  False          False       False                    False
# ...                  ...            ...         ...                      ...
# 244454             False          False       False                    False
# 244455             False          False       False                    False
# 244456             False          False       False                    False
# 244457             False          False       False                    False
# 244458             False          False       False                    False
#
#         transaction_num
# 0                 False
# 1                 False
# 2                 False
# 3                 False
# 4                 False
# ...                 ...
# 244454            False
# 244455            False
# 244456            False
# 244457            False
# 244458            False
#
# [239979 rows x 15 columns]

# %% [markdown]
# ## Model prep

# %%
model_df = contract_df.copy()
model_df.drop(columns = ['contract_transaction_unique_key', 'contract_award_unique_key', 'first_date', 'action_date'], inplace = True)

model_df['Transaction_Deob'] = model_df['Transaction_Deob'].astype(int)
# model_df['Contract_deob'] = model_df['Contract_deob'].astype(int)
model_df['days_since_first_action'] = model_df['days_since_first_action'].astype(int)
model_df['days_since_first_action'] = model_df['days_since_first_action'].apply(lambda x: x/(60 * 60 * 24 * 1000000000))

# model_df.head()
model_df = model_df.fillna(0)
print('row ct before removing potential values of 0', model_df.shape[0])

model_df_new = model_df[model_df['potential_total_value_of_award'] != 0]

print('row ct before after potential values of 0', model_df_new.shape[0])
print('OK, don\'t wanna do that')

model_df.drop(columns = 'Percent Cumulatively Obligated over potential total value of award', inplace = True)



print(model_df.max(axis = 0))

print(model_df['Contract_deob'].value_counts())
print(model_df['Transaction_Deob'].value_counts())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-9117b18b6752> in <module>
#       4 model_df['Transaction_Deob'] = model_df['Transaction_Deob'].astype(int)
#       5 # model_df['Contract_deob'] = model_df['Contract_deob'].astype(int)
# ----> 6 model_df['days_since_first_action'] = model_df['days_since_first_action'].astype(int)
#       7 model_df['days_since_first_action'] = model_df['days_since_first_action'].apply(lambda x: x/(60 * 60 * 24 * 1000000000))
#       8
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors, **kwargs)
#    5880             # else, only a single dtype is given
#    5881             new_data = self._data.astype(
# -> 5882                 dtype=dtype, copy=copy, errors=errors, **kwargs
#    5883             )
#    5884             return self._constructor(new_data).__finalize__(self)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, **kwargs)
#     579
#     580     def astype(self, dtype, **kwargs):
# --> 581         return self.apply("astype", dtype=dtype, **kwargs)
#     582
#     583     def convert(self, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     436                     kwargs[k] = obj.reindex(b_items, axis=axis, copy=align_copy)
#     437
# --> 438             applied = getattr(b, f)(**kwargs)
#     439             result_blocks = _extend_blocks(applied, result_blocks)
#     440
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in astype(self, dtype, copy, errors, values, **kwargs)
#     557
#     558     def astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
# --> 559         return self._astype(dtype, copy=copy, errors=errors, values=values, **kwargs)
#     560
#     561     def _astype(self, dtype, copy=False, errors="raise", values=None, **kwargs):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\internals\blocks.py in _astype(self, dtype, copy, errors, values, **kwargs)
#     641                     # _astype_nansafe works fine with 1-d only
#     642                     vals1d = values.ravel()
# --> 643                     values = astype_nansafe(vals1d, dtype, copy=True, **kwargs)
#     644
#     645                 # TODO(extension)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\dtypes\cast.py in astype_nansafe(arr, dtype, copy, skipna)
#     691         raise TypeError(
#     692             "cannot astype a timedelta from [{from_dtype}] "
# --> 693             "to [{to_dtype}]".format(from_dtype=arr.dtype, to_dtype=dtype)
#     694         )
#     695
#
# TypeError: cannot astype a timedelta from [timedelta64[ns]] to [int32]

# %%
from sklearn.model_selection import train_test_split

# %%
labels = np.array(model_df['Contract_deob'])
features = model_df.copy()
features.drop(columns = ['Contract_deob'], inplace = True)
features_list = list(features.columns)
features = np.array(features)

print('Features going into model: \n', features_list)

# %%
train_features, test_features, train_labels, test_labels = train_test_split(features, labels, test_size = 0.2, random_state = 42)

# %%
print(test_features.shape)
print(features.shape)
print(train_features.shape)
print(test_labels.shape)

print(np.min(labels))

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)

rf.fit(train_features, train_labels)

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
# Calculate the absolute errors

errors = abs(predictions - test_labels)

print(len(errors))

num_errors = len(np.where(errors == 1))

print(num_errors)

conf_matrix = np.column_stack((predictions, test_labels))

print(conf_matrix)
print(type(conf_matrix))

results_df = pd.DataFrame(conf_matrix, columns = ['Pred', 'Actual'])

# results_df.rename(columns = {'0': 'Pred', '1': 'Actual'}, inplace = True)
results_df.head()

results_df.groupby(['Pred', 'Actual']).count()

# print('test labels: \n', test_labels)
# test_labels_1 = np.where(test_labels == 1)
# print(len(test_labels_1))

# # Print out the mean absolute error (mae)
# print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')

# %%
print(np.min(test_labels))
print(np.min(train_labels))

# %%
df = df.fillna(0)
# Convert action date to pd.datetime
df['action_date'] = pd.to_datetime(df['action_date'])
# set index to each contract and date
df.set_index(['contract_award_unique_key','action_date'], inplace = True)
df.sort_index()

# %%
# We want to only focus on execution rate (for now). I'm not sure which column is the best indicator of execution rate
# we can follow up with Eric. I'm going to stick with Percent Cumulatively Obligated over potential total value of award
# as wequal to the execution rate.
drop_columns = [column for column in df.columns if column != 'Percent Cumulatively Obligated over potential total value of award']
df.drop(drop_columns,axis = 1, inplace=True)

df.rename(columns = {'Percent Cumulatively Obligated over potential total value of award':'execution_rate'},inplace = True)

# %%
df.head(4)

# %%
contracts = [contract for contract, date in list(df.index)]
unique_k = set(contracts)
print('This is the number of unique Contracts: ' + str(len(unique_k)))
print('This is the number of transactions: ' + str(len(contracts)))

# %% [markdown]
# # Selecting contracts w/ 5 or more transactions from 2008-2018

# %%
# I grouped the dataframe by contract and used the .count(method)
# to determine the number of entries. I then used an inequality to get a boolean series of the number of contracts 
# that satisfied the condition of at least 5 transactions.
test = df.groupby(level='contract_award_unique_key')['execution_rate'].count() >= 5
test = test[test==True]
# This is the list of contracts that have more than 5 transactions. 
highlighted_transactions = test.index

# %% [markdown]
# ### Utilize FY19 Data as Test Data

# %%
os.chdir('C:\\Users\\belincoln\\repos\\BudgetPredict')

# %%
# %cd data

# %%
filename = 'FY2019_070_Contracts_Full_20200110_1.csv'

# %%
test_df = pd.read_csv(filename, header = 0, usecols = ['contract_transaction_unique_key',
                        'contract_award_unique_key',
                        'federal_action_obligation','total_dollars_obligated', 'base_and_exercised_options_value', 
                        'current_total_value_of_award', 'base_and_all_options_value','potential_total_value_of_award',
                        'action_date'],
                 dtype = {'contract_transaction_unique_key':'str','contract_transaction_unique_key':'str',
                          'federal_action_obligation': 'float','total_dollars_obligated': 'float', 
                          'base_and_exercised_options_value': 'float', 'current_total_value_of_award': 'float', 
                          'base_and_all_options_value': 'float','potential_total_value_of_award': 'float',
                          'action_date':'str'})

# %%
print('This is the # of transactions is FY19 for DHS: ' + str(len(test_df)))

# %%
test_df = test_df.fillna(0)
# Convert action date to pd.datetime
test_df['action_date'] = pd.to_datetime(test_df['action_date'])
# set index to each contract and date
test_df.set_index(['contract_award_unique_key','action_date'], inplace = True)
test_df.sort_index()
fy19_df = test_df.copy()

# %%
# We want to only focus on execution rate (for now). I'm not sure which column is the best indicator of execution rate
# we can follow up with Eric. I'm going to stick with Percent Cumulatively Obligated over potential total value of award
# as wequal to the execution rate.
drop_columns = [column for column in test_df.columns if column != 'Percent Cumulatively Obligated over potential total value of award']
test_df.drop(drop_columns,axis = 1, inplace=True)

test_df.rename(columns = {'Percent Cumulatively Obligated over potential total value of award':'execution_rate'},inplace = True)

# %%
contracts = [contract for contract, date in list(test_df.index)]
unique_k_fy19 = set(contracts)
print('This is the number of unique Contracts: ' + str(len(unique_k_fy19)))
print('This is the number of transactions: ' + str(len(contracts)))

# %%
type(unique_k_fy19)

# %%
highlighted_transactions = set(highlighted_transactions)

# %%
len(unique_k_fy19.intersection(highlighted_transactions))

# %%
mask = list(unique_k_fy19.intersection(highlighted_transactions))

# %%
fy19_df.index.get_level_values('contract_award_unique_key')

# %%
highlighted_fy19 = fy19_df.loc[(list(highlighted_transactions), slice(None)),:]

# %%
highlighted_fy19.head()

# %%
highlighted_fy19.index.get_level_values(0).unique()

# %%
highlighted_fy19

# %%
highlighted_fy19.drop('base_and_exercised_options_value',axis = 1, inplace = True)

# %%
df = highlighted_fy19

# %%
# Create 3 new features for analysis
df['Percent awarded over potential total awarded'] = df['current_total_value_of_award'] / df['potential_total_value_of_award']
df['Percent Cumulatively Obligated over potential total value of award'] = df['total_dollars_obligated'] / df['potential_total_value_of_award']
df['Percent Cumulatively Obligated over total value already awarded'] = df['total_dollars_obligated'] / df['current_total_value_of_award']

# Create Indicator Variable
df['Indicator'] = df['federal_action_obligation']<-1000

# set index to each transaction key
df.set_index('contract_transaction_unique_key', inplace = True)

# %%
df.drop('federal_action_obligation', axis =1, inplace = True)
df = df.fillna(0)

# %%
# This is the percentage of De-Obligations in the sample (before test/train split)
print('Total number of De-Obligations: ' +str(df['Indicator'].sum()))
print('Percentage of De-Obligations: '+str(df['Indicator'].sum()/len(df)))

# %%
# Create matrix of feature variables and our dependent variable
X, y =  df.iloc[:,1:-1], df.loc[:,'Indicator']

# convert y to np.array of 0s and 1s
y = np.array(y.astype(int))

# %%
#train the data 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_test.shape

# %%
# Setup the data matrix appropriately, and add ones for the intercept term
m_train, n_train = X_train.shape
m_test, n_test = X_test.shape
# Add intercept term to X
X_train = np.concatenate([np.ones((m_train, 1)), X_train], axis=1)
X_test = np.concatenate([np.ones((m_test, 1)), X_test], axis=1)

# %%
log_model = LogisticRegression().fit(X_train, y_train)

# %%
# Coefficents to multiply features by
log_model.coef_

# %%
theta = log_model.coef_[0]

# %%
print(theta[0])

# %%
def sigmoid(z):
    """
    Compute sigmoid function given the input z.
    
    Parameters
    ----------
    z : array_like
        The input to the sigmoid function. This can be a 1-D vector 
        or a 2-D matrix. 
    
    Returns
    -------
    g : array_like
        The computed sigmoid function. g has the same shape as z, since
        the sigmoid is computed element-wise on z.
        
    Instructions
    ------------
    Compute the sigmoid of each value of z (z can be a matrix, vector or scalar).
    """
    # convert input to a numpy array
    z = np.array(z)
    
    # You need to return the following variables correctly 
    g = np.zeros(z.shape)

    temp = 1 + np.power(np.e,-z)
    g = 1 / temp
    

    return g

# %%
pred = sigmoid(np.dot(X_test,theta))

# %%
fig = pyplot.figure
pyplot.scatter(np.arange(len(pred)), pred)

# %%
# Now we will test our model using the test_set
pred = sigmoid(np.dot(X_test,theta))

# %%
# Convert probabilty of de-obligation into prediction
pred = pred > .5
# Convert to int
pred = np.array(pred.astype(int))

# %%
test = pred == y_test

# %%
test.sum()/len(test)

# %%
# Really what we are looking for here 
# is how many times a de-obligation occured and we were able to predict it?

# %%
# Also percentage of false positives: how many times did we predict a de-obligation and 
# it did not occur?

# %%
data = {'predicted value' : pred, 'test value': y_test}
testdf = pd.DataFrame(data)

# %%
# %%HTML
# <style type="text/css">
# table.dataframe td, table.dataframe th {
#     border: 1px  black solid !important;
#   color: black !important;
# }
# </style>

# %%
cm = np.array(confusion_matrix(pred, y_test, labels = [1,0]))
confusion = pd.DataFrame(cm, index=[['Predicted', 'Predicted'], ['Large De-Obligation','Obligation']],
                         columns = [['Test Results', 'Test Results'],['Large De-Obligation','Obligation']])
confusion

# %%
confusion.iloc[0].sum()+confusion.iloc[1].sum()

# %%
correct_preds = testdf[testdf['test value'] == 1]
correct_preds2 = correct_preds[correct_preds['predicted value'] ==1]
print('Size of Test set: ' + str(len(testdf)))
print('Size of Train set: ' + str(len(X_train)))
print('Percentage of correct predictions (Accuracey): ' + str((confusion.iloc[0,0] + confusion.iloc[1,1])/len(testdf)))
print('Percentage of significant de-obligations: ' + str(len(correct_preds)/len(testdf)))
print('Percentage of de-obligations correctly predicted: ' + str(len(correct_preds2)/len(correct_preds)))

# %%
# Rate of False Negatives: A de-obligation occurs, but the model did not predict it. 
false_neg = testdf[testdf['predicted value'] == 0]
false_neg2 = false_neg[false_neg['test value'] == 1]
print('Number of False Negatives : ' + str(len(false_neg2)))
print('Rate of False Negative: ' + str(len(false_neg2)/len(testdf)))

# %%
# Show the rate of False Positives: Times the model predicted a de-obligation, yet there wasn't one

false_pos = testdf[testdf['predicted value'] == 1]
false_pos2 = false_pos[false_pos['test value'] == 0]

print('Number of False Positives: ' + str(len(false_pos2)))
print('Rate of False Positives: ' + str(len(false_pos2)/len(testdf)))
